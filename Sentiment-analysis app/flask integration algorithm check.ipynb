# %%
import pickle

# Load the trained model
with open(r"C:\internship -1\AIML-internship-2025\Sentiment-analysis app\model.pkl", "rb") as f:
    model = pickle.load(f)

# Print model type
print("Model type:", type(model))
# Out:
# Model type: <class 'sklearn.linear_model._logistic.LogisticRegression'>
